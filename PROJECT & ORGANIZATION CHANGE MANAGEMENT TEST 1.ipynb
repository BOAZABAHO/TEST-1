# %%
#PROJECT & ORGANIZATION CHANGE MANAGEMENT TEST
#ABAHO BOAZ
#lets import libralies for our codes
import pandas as pd
import numpy as np

# %%
#loading data set
df=pd.read_csv("COVID_19 AMERICA 7.10.2021 1810PM.csv", sep=",")
df
# Out:
#                                   Name WHO Region  Cases - cumulative total  \
# 0                              Bahamas   Americas                     12407
# 1             Turks and Caicos Islands   Americas                      2424
# 2                  Antigua and Barbuda   Americas                      1263
# 3                     Saint Barthélemy   Americas                      1040
# 4               British Virgin Islands   Americas                       295
# 5                             Dominica   Americas                       192
# 6             United States of America   Americas                  33257768
# 7                               Brazil   Americas                  18169881
# 8                            Argentina   Americas                   4326101
# 9                             Colombia   Americas                   4027016
# 10                              Mexico   Americas                   2487747
# ...

# %%
df.head()
# Out:
#                        Name WHO Region  Cases - cumulative total  \
# 0                   Bahamas   Americas                     12407
# 1  Turks and Caicos Islands   Americas                      2424
# 2       Antigua and Barbuda   Americas                      1263
# 3          Saint Barthélemy   Americas                      1040
# 4    British Virgin Islands   Americas                       295
#
#    Cases - cumulative total per 100000 population  \
# 0                                         3155.04
# 1                                         6260.65
# 2                                         1289.71
# 3                                        10520.99
# 4                                          975.63
#
#    Cases - newly reported in last 7 days  \
# 0                                    112
# 1                                      1
# 2                                      0
# 3                                      8
# 4                                      0
#
# ...

# %%
df.tail()
# Out:
#                            Name WHO Region  Cases - cumulative total  \
# 51                         Saba   Americas                         7
# 52                      Bermuda   Americas                      2504
# 53               Cayman Islands   Americas                       609
# 54  Falkland Islands (Malvinas)   Americas                        60
# 55    Saint Pierre and Miquelon   Americas                        26
#
#     Cases - cumulative total per 100000 population  \
# 51                                          362.13
# 52                                         4021.00
# 53                                          926.66
# 54                                         1722.65
# 55                                          448.66
#
#     Cases - newly reported in last 7 days  \
# 51                                      0
# 52                                      5
# 53                                     10
# 54                                      0
# ...

# %%
df.dtypes
# Out:
# Name                                                             object
# WHO Region                                                       object
# Cases - cumulative total                                          int64
# Cases - cumulative total per 100000 population                  float64
# Cases - newly reported in last 7 days                             int64
# Cases - newly reported in last 7 days per 100000 population     float64
# Cases - newly reported in last 24 hours                           int64
# Deaths - cumulative total                                         int64
# Deaths - cumulative total per 100000 population                 float64
# Deaths - newly reported in last 7 days                            int64
# Deaths - newly reported in last 7 days per 100000 population    float64
# Deaths - newly reported in last 24 hours                          int64
# Transmission Classification                                      object
# dtype: object

# %%
df.describe()
# Out:
#        Cases - cumulative total  \
# count              5.600000e+01
# mean               1.275874e+06
# std                5.038072e+06
# min                7.000000e+00
# 25%                2.057250e+03
# 50%                1.525500e+04
# 75%                3.294828e+05
# max                3.325777e+07
#
#        Cases - cumulative total per 100000 population  \
# count                                       56.000000
# mean                                      3935.451429
# std                                       3243.103255
# min                                         96.640000
# 25%                                       1265.932500
# 50%                                       3053.085000
# 75%                                       6197.410000
# max                                      10520.990000
#
#        Cases - newly reported in last 7 days  \
# count                              56.000000
# mean                            20456.053571
# ...

# %%
df.shape
# Out:
# (56, 13)

# %%
# %%capture
# !pip install seaborn

# %%
df['Transmission Classification'].value_counts().to_frame()
# Out:
#                         Transmission Classification
# Community transmission                           41
# Clusters of cases                                 6
# No cases                                          5
# Sporadic cases                                    4

# %% [markdown]
# # Simple Linear Regression

# %%
#import matplotlib.pyplot as plt
#import numpy as np
#%conda install sklearn
#%matplotlib inline
#from sklearn.linear_model import linearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
#Using identified cases for the next 24 hours
x=df[['Cases - newly reported in last 24 hours']]
y=df['Deaths - newly reported in last 24 hours']

# %%
lm=LinearRegression()
lm.fit(x,y)
yhat=lm.predict(x)
yhat[0:5]
# Out:
# array([9.95968105, 9.95968105, 9.95968105, 9.95968105, 9.95968105])

# %%
#calculation of coefficient m
lm.coef_
# Out:
# array([0.02106987])

# %%
#intercept c
lm.intercept_
# Out:
# 9.95968105413516

# %%
#calculating r-squared
lm.score(x,y)
# Out:
# 0.9855145590117684

# %% [markdown]
# y=mx+c
# $$Deaths - newly reported in last 24 hours=0.02106987xCases - newly reported in last 24 hours+9.95968105413516$$

# %%
#Let's import the function mean_squared_error from the module metrics
from sklearn.metrics import mean_squared_error

# %%
#RMSE
y=lm.predict(x)
MSE = mean_squared_error(df['Deaths - newly reported in last 24 hours'], y)
print('MSE is', MSE)
# Out:
# MSE is 1674.166108155738

# %%
#calculate RSME
#import necessary libraries
from math import sqrt

# %%
sqrt(mean_squared_error(df['Deaths - newly reported in last 24 hours'], y))
# Out:
# 40.9165749807549

# %% [markdown]
# # Multiple LinearRegression

# %% [markdown]
# Predicting Deaths-newly reported in last 24 hours in America by looking at; Cases - newly reported in last 7 days,cases - cumulative total per 100000 population, and Cases - newly reported in last 24 hours
#
#
# Model formulae;
# $$𝑦=𝑏1𝑥1+𝑏2𝑥2+b3x3+𝑐$$

# %%
# The different variables here are; Cases - newly reported in last 7 days, cases - cumulative total per 100000 population and Cases,Cases - newly reported in last 24 hours
z = df[['Cases - newly reported in last 7 days', 'Cases - cumulative total per 100000 population','Cases - newly reported in last 24 hours']]

# %%
#Fitting the linear model using the three above-mentioned variables.
lm.fit(z, df['Deaths - newly reported in last 24 hours'])
# Out:
# LinearRegression()

# %%
#calculation of coefficient b1,b2,b3 
lm.coef_
# Out:
# array([0.0002005 , 0.00085955, 0.02005241])

# %%
#intercept 
lm.intercept_
# Out:
# 6.396806461731813

# %%
#calculating r-squared
lm.score(z, df['Deaths - newly reported in last 24 hours'])
# Out:
# 0.9856121774537552

# %%
#Calculating the Mean Squared Error (MSE)
#prediction based on our model
y_predict_multifit = lm.predict(z)
#Now we can compare the predicted results with the actual results
mean_squared_error(df['Deaths - newly reported in last 24 hours'], y_predict_multifit)
# Out:
# 1662.883780801116

# %%
#calculating RMSE
sqrt(mean_squared_error(df['Deaths - newly reported in last 24 hours'], y_predict_multifit))
# Out:
# 40.778472026316976

# %% [markdown]
# # The best design model to predict the number of deaths due to Covid_19 pandemic in Americas Region is Multiple Linear Regression.

# %% [markdown]
# # Reason

# %% [markdown]
# # r-square for Multiple Linear Regression = 0.9856121774537552 which is Higher than the r-square for Simple LinearRegression = 0.9855145590117684
